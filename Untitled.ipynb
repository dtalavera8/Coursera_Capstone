# %%
import random
import math
import matplotlib.pyplot as plt

# %%
x= [random.randrange(0,500,1) for i in range(500)]

# %%
y=[random.randrange(0,500,1) for i in range(500)]

# %%
plt.figure(figsize=(20,16))
plt.scatter(x,y, s=100)
